# %% [markdown]
# ## Results
#
# Predict rainfall in the African Sahel region with various machine learning and deep learning methods. Results are shown separately for each ESM (CESM and FOCI) and lead time (0 / 1 / 3 / 6 months), ordered by mean squared error of predicted vs. true target (in ascending order) and then by the correlation coefficient (in descending order).

# %% [markdown]
# ### Tech preamble

# %%
import pandas as pd
from IPython.display import display

# %%
# Store ALL results in JSON format:
results = {
    'ESM': ['CESM',
            'CESM',
            'CESM',
            'CESM',
            'FOCI',
            'FOCI',
            'FOCI',
            'FOCI',
            'CESM',
            'CESM',
            'FOCI',
            'FOCI',
            'CESM',
            'CESM',
            'CESM',
            'FOCI',
            'FOCI',
            'FOCI',
            'CESM',
            'CESM',
            'CESM',
            'FOCI',
            'FOCI',
            'FOCI',
            'CESM',
            'CESM',
            'CESM',
            'FOCI',
            'FOCI',
            'FOCI',
            'CESM',
            'CESM',
            'CESM',
            'FOCI',
            'FOCI',
            'FOCI',
            'CESM',
            'CESM',
            'CESM',
            'FOCI',
            'FOCI',
            'FOCI',
            'CESM',
            'CESM',
            'CESM',
            'FOCI',
            'FOCI',
            'FOCI',
           ],
    'lead': [0,
             1,
             3,
             6,
             0,
             1,
             3,
             6,
             1,
             1,
             1,
             1,
             1,
             3,
             6,
             1,
             3,
             6,
             1,
             3,
             6,
             1,
             3,
             6,
             1,
             3,
             6,
             1,
             3,
             6,
             1,
             3,
             6,
             1,
             3,
             6,
             1,
             3,
             6,
             1,
             3,
             6,
             1,
             3,
             6,
             1,
             3,
             6,
             ],
    'author': ['Marco',
               'Marco',
               'Marco',
               'Marco',
               'Marco',
               'Marco',
               'Marco',
               'Marco',
               'Marco',
               'Marco',
               'Marco',
               'Marco',
               'Marco',
               'Marco',
               'Marco',
               'Marco',
               'Marco',
               'Marco',
               'Marco',
               'Marco',
               'Marco',
               'Marco',
               'Marco',
               'Marco',
               'Marco',
               'Marco',
               'Marco',
               'Marco',
               'Marco',
               'Marco',
               'Marco',
               'Marco',
               'Marco',
               'Marco',
               'Marco',
               'Marco',
               'Marco',
               'Marco',
               'Marco',
               'Marco',
               'Marco',
               'Marco',
               'Marco',
               'Marco',
               'Marco',
               'Marco',
               'Marco',
               'Marco',
               ],
    'model': ['linReg',
              'linReg',
              'linReg',
              'linReg',
              'linReg',
              'linReg',
              'linReg',
              'linReg',
              'heuristic',
              'heuristic',
              'heuristic',
              'heuristic',
              'CNN/fc',
              'CNN/fc',
              'CNN/fc',
              'CNN/fc',
              'CNN/fc',
              'CNN/fc',
              'CNN/fc',
              'CNN/fc',
              'CNN/fc',
              'CNN/fc',
              'CNN/fc',
              'CNN/fc',
              'CNN/fc',
              'CNN/fc',
              'CNN/fc',
              'CNN/fc',
              'CNN/fc',
              'CNN/fc',
              'LSTM/fc',
              'LSTM/fc',
              'LSTM/fc',
              'LSTM/fc',
              'LSTM/fc',
              'LSTM/fc',
              'LSTM/fc',
              'LSTM/fc',
              'LSTM/fc',
              'LSTM/fc',
              'LSTM/fc',
              'LSTM/fc',
              'LSTM/fc',
              'LSTM/fc',
              'LSTM/fc',
              'LSTM/fc',
              'LSTM/fc',
              'LSTM/fc',
              ],
    'variant': ['all inputs except PREC_SAHEL',
                'all inputs',
                'all inputs',
                'all inputs',
                'all inputs except PREC_SAHEL',
                'all inputs',
                'all inputs',
                'all inputs',
                'previous month',
                'previous year',
                'previous month',
                'previous year',
                'univariate',
                'univariate',
                'univariate',
                'univariate',
                'univariate',
                'univariate',
                'all inputs',
                'all inputs',
                'all inputs',
                'all inputs',
                'all inputs',
                'all inputs',
                'all inputs, with months',
                'all inputs, with months',
                'all inputs, with months',
                'all inputs, with months',
                'all inputs, with months',
                'all inputs, with months',                
                'univariate',
                'univariate',
                'univariate',
                'univariate',
                'univariate',
                'univariate',
                'all inputs',
                'all inputs',
                'all inputs',
                'all inputs',
                'all inputs',
                'all inputs',
                'all inputs, with months',
                'all inputs, with months',
                'all inputs, with months',
                'all inputs, with months',
                'all inputs, with months',
                'all inputs, with months',                
                ],
    'mse': [0.854,
            0.999,
            1.054,
            1.057,
            0.7,
            0.775,
            0.801,
            0.817,
            1.739,
            2.328,
            1.324,
            1.47,
            1.083,
            1.092,
            1.093,
            0.805,
            0.825,
            0.826,
            1.022,
            1.050,
            1.055,
            0.814,
            0.821,
            0.836,
            0.979,
            0.985,
            1.043,
            0.791,
            0.822,
            0.818,
            1.066,
            1.098,
            1.098,
            0.796,
            0.825,
            0.825,
            0.943,
            0.984,
            1.016,
            0.795,
            0.790,
            0.837,
            0.916,
            0.938,
            0.987,
            0.759,
            0.779,
            0.842,
            ],
    'correl': [0.475,
               0.301,
               0.199,
               0.189,
               0.384,
               0.24,
               0.145,
               0.071,
               0.207,
               0.187,
               -0.058,
               0.089,
               0.110,
               0.076,
               0.075,
               0.167,
               0.003,
               0.015,
               0.263,
               0.214,
               0.206,
               0.116,
               0.070,
               0.040,
               0.339,
               0.319,
               0.232,
               0.207,
               0.097,
               0.081,
               0.170,
               0.009,
               0.002,
               0.194,
               0.006,
               -0.000,
               0.383,
               0.326,
               0.277,
               0.243,
               0.186,
               0.081,
               0.418,
               0.393,
               0.321,
               0.306,
               0.225,
               0.099,
               ],
}

# Convert to pandas dataframe:
results_all = pd.DataFrame(results)

## Show results separately for both ESMs (CESM and FOCI) and all lead times (0, 1, 3, 6 months):

# Loop over ESMs:
for ESM in ['CESM', 'FOCI']:
    
    # Loop over lead times:
    for lead in [0, 1, 3, 6]:
        
        # Get subset of results, according to current ESM and lead time:
        results_subset = results_all.loc[results_all['ESM'] == ESM].loc[results_all['lead'] == lead]
        
        # Sort by mse (ascending order) and then by correlation coefficient (descending order):
        results_subset = results_subset.sort_values(by=['mse', 'correl'], ascending=[True, False])
        
        # Reset index for subset:
        results_subset = results_subset.reset_index(drop=True)
        
        # Start index from ONE:
        results_subset.index += 1
        
        # Show subset of results as table:
        display(results_subset)
# Out:
#     ESM  lead author   model                       variant    mse  correl
# 1  CESM     0  Marco  linReg  all inputs except PREC_SAHEL  0.854   0.475
#     ESM  lead author      model                  variant    mse  correl
# 1  CESM     1  Marco    LSTM/fc  all inputs, with months  0.916   0.418
# 2  CESM     1  Marco    LSTM/fc               all inputs  0.943   0.383
# 3  CESM     1  Marco     CNN/fc  all inputs, with months  0.979   0.339
# 4  CESM     1  Marco     linReg               all inputs  0.999   0.301
# 5  CESM     1  Marco     CNN/fc               all inputs  1.022   0.263
# 6  CESM     1  Marco    LSTM/fc               univariate  1.066   0.170
# 7  CESM     1  Marco     CNN/fc               univariate  1.083   0.110
# 8  CESM     1  Marco  heuristic           previous month  1.739   0.207
# 9  CESM     1  Marco  heuristic            previous year  2.328   0.187
#     ESM  lead author    model                  variant    mse  correl
# 1  CESM     3  Marco  LSTM/fc  all inputs, with months  0.938   0.393
# 2  CESM     3  Marco  LSTM/fc               all inputs  0.984   0.326
# 3  CESM     3  Marco   CNN/fc  all inputs, with months  0.985   0.319
# 4  CESM     3  Marco   CNN/fc               all inputs  1.050   0.214
# 5  CESM     3  Marco   linReg               all inputs  1.054   0.199
# 6  CESM     3  Marco   CNN/fc               univariate  1.092   0.076
# 7  CESM     3  Marco  LSTM/fc               univariate  1.098   0.009
#     ESM  lead author    model                  variant    mse  correl
# 1  CESM     6  Marco  LSTM/fc  all inputs, with months  0.987   0.321
# 2  CESM     6  Marco  LSTM/fc               all inputs  1.016   0.277
# 3  CESM     6  Marco   CNN/fc  all inputs, with months  1.043   0.232
# 4  CESM     6  Marco   CNN/fc               all inputs  1.055   0.206
# 5  CESM     6  Marco   linReg               all inputs  1.057   0.189
# 6  CESM     6  Marco   CNN/fc               univariate  1.093   0.075
# 7  CESM     6  Marco  LSTM/fc               univariate  1.098   0.002
#     ESM  lead author   model                       variant  mse  correl
# 1  FOCI     0  Marco  linReg  all inputs except PREC_SAHEL  0.7   0.384
#     ESM  lead author      model                  variant    mse  correl
# 1  FOCI     1  Marco    LSTM/fc  all inputs, with months  0.759   0.306
# 2  FOCI     1  Marco     linReg               all inputs  0.775   0.240
# 3  FOCI     1  Marco     CNN/fc  all inputs, with months  0.791   0.207
# 4  FOCI     1  Marco    LSTM/fc               all inputs  0.795   0.243
# 5  FOCI     1  Marco    LSTM/fc               univariate  0.796   0.194
# 6  FOCI     1  Marco     CNN/fc               univariate  0.805   0.167
# 7  FOCI     1  Marco     CNN/fc               all inputs  0.814   0.116
# 8  FOCI     1  Marco  heuristic           previous month  1.324  -0.058
# 9  FOCI     1  Marco  heuristic            previous year  1.470   0.089
#     ESM  lead author    model                  variant    mse  correl
# 1  FOCI     3  Marco  LSTM/fc  all inputs, with months  0.779   0.225
# 2  FOCI     3  Marco  LSTM/fc               all inputs  0.790   0.186
# 3  FOCI     3  Marco   linReg               all inputs  0.801   0.145
# 4  FOCI     3  Marco   CNN/fc               all inputs  0.821   0.070
# 5  FOCI     3  Marco   CNN/fc  all inputs, with months  0.822   0.097
# 6  FOCI     3  Marco  LSTM/fc               univariate  0.825   0.006
# 7  FOCI     3  Marco   CNN/fc               univariate  0.825   0.003
#     ESM  lead author    model                  variant    mse  correl
# 1  FOCI     6  Marco   linReg               all inputs  0.817   0.071
# 2  FOCI     6  Marco   CNN/fc  all inputs, with months  0.818   0.081
# 3  FOCI     6  Marco  LSTM/fc               univariate  0.825  -0.000
# 4  FOCI     6  Marco   CNN/fc               univariate  0.826   0.015
# 5  FOCI     6  Marco   CNN/fc               all inputs  0.836   0.040
# 6  FOCI     6  Marco  LSTM/fc               all inputs  0.837   0.081
# 7  FOCI     6  Marco  LSTM/fc  all inputs, with months  0.842   0.099
